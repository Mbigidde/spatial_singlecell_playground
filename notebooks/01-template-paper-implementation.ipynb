# %% [markdown]
# # Paper Implementation: [Paper Title Here]
#
# - **Paper:** [citation, link]
# - **Domain:** single-cell / spatial
# - **Task:** e.g., cell type classification, spatial domain detection
# - **Input:** describe shape (e.g., n_cells x n_genes)
# - **Output:** describe (e.g., class probabilities, embeddings)

# %% [markdown]
# ## 1. Paper Summary
#
# - Key idea:
# - Model components:
# - Loss function:

# %% [markdown]
# ## 2. Data Setup
#
# - Dataset used:
# - Preprocessing steps:

# %% [markdown]
# ## 3. Model Implementation
#
# - Encoder:
# - Decoder / heads:

# %% [markdown]
# ## 4. Training
#
# - Hyperparameters:
# - Metrics:

# %% [markdown]
# ## 5. Results & Notes
#
# - Plots:
# - What worked / didn’t:
