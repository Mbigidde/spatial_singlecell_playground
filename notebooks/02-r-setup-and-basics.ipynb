# %%
print("welcome to R")
(5*2-7^2)
y = sum(50,3,1)
x = "something to print"
z = "4"
print(x)
# check data type using str for structure
str(x)
str(y)
str(z)
# changing data types; so say change z to numeric
z = str(as.numeric(z))
print(str(z))
# Vectors
# create a vector using c for concatenate
listofvectors = c(3,4,5,8,6,9,10,34) # When you do math to a vector,
# it happens to every number in the vector. So;
print(2*listofvectors)
# we can look at particular componenets of the vector by indexing the positions just like in python
# difference is in python indexes start at 0 in R they start at 1. So;
listofvectors[1]
listofvectors[-1] # also notice this doesnt work as it would in python as in py we would expect it to return 34
# in R this just says return everythinh in the vector minus the value at position 1
# i wonder how splicing works in R
listofvectors[1:3] # returns values including the one in the 3 position python  would return values at 1 and 2 only
# Out:
# [1] "welcome to R"
# [1] -39
# [1] "something to print"
#  chr "something to print"
#  num 54
#  chr "4"
#  num 4
#  NULL
# NULL
# [1]  6  8 10 16 12 18 20 68
# [1] 3
# [1]  4  5  8  6  9 10 34
# [1] 3 4 5

# %%
# Loading Data into R
# To read data into R, you need to specify the data structure and location where to find the data.
# to use the data frame structure we have to use a package as its not native to R
# Packge we use is tidyverse
# so then can we also use pyton to create our dataframes then import them into R with tidyverse????
# import package using library() func instead of import
library(tidyverse)
# load data as you would in python
data = read_csv("")
list.files(folderpath) # to list files in a folder

# %%
# Inspect data
head(data)
head(data, 5) # as opposed to py which is data.head(5)
tail(data, 3)
# to access data in the dataframe we do so by referencing the indexes of RC(row column)
data [2,4] # will return whatever is in the 2nd row 4th column
data [2,] # everything in the 2nd row
data [4] # everything in the 4th column so as long as you dont add a comma it will return column
head(data[4]) # head summary of the 4th column 
# Remove unwanted data
data = data[-1,] # brings up all rows and columns apart from the first row
# return the column names of all columns in the dataframe object
columnnames = names(data)
# rename the column names
names(data) = c("new_name for column 1"........)
# the names()func is the same as colnames()func and there is also rownames()func
gsub() # global substitution that finds all occurrences of a pattern and replaces them.
# gsub(pattern ("[[:space:]+]"), replacement("_"), text(names(Data))) 
# So, to remove spaces in column names
names(data) = gsub("[[:space:]+]", "_", names(Data))) 
# remove %ge from a column so that you turn the values into numerics instead of char
data$columnname = gsub("%", "", data$columnname)
# Out:
#
# 1 function (..., list = character(), package = NULL, lib.loc = NULL,
# 2     verbose = getOption("verbose"), envir = .GlobalEnv, overwrite = TRUE)
# 3 {
# 4     fileExt <- function(x) {
# 5         db <- grepl("\\\\.[^.]+\\\\.(gz|bz2|xz)$", x)
# 6         ans <- sub(".*\\\\.", "", x)
#
# 1 function (..., list = character(), package = NULL, lib.loc = NULL,
# 2     verbose = getOption("verbose"), envir = .GlobalEnv, overwrite = TRUE)
# 3 {
# 4     fileExt <- function(x) {
# 5         db <- grepl("\\\\.[^.]+\\\\.(gz|bz2|xz)$", x)
#
# 151     }
# 152     invisible(names)
# 153 }
# Error in data[2, 4]: object of type 'closure' is not subsettable
# Traceback:

# %%
# summarise data statistics
# Data cleaning 
        # check datatype with str(data) anything that comes after a $ is a column
            # inspect a specific column and retrive its values 
head(data$columnname) # the first few values in columnname
        # type_convert func automatically converts the data types of our data_frame
data = type_convert(data)

# gives a summary for each column in the dataframe
summary(data)
